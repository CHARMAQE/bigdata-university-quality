# %%
import pandas as pd

# Columns: code_module, code_presentation, id_student, gender, region, highest_education,
#         imd_band, age_band, num_of_prev_attempts, studied_credits, disability, final_result

df_info = pd.read_csv('/Users/hamzacharmaqe/Documents/Last Year/Project Metier/BigData_University_Quality/3_Data/Raw/OULAD/studentInfo.csv')
print(df_info.head(3))
print(df_info.shape)  # (32593, 12)
print(df_info['final_result'].value_counts())
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# 2               60          Y    Withdrawn
# (32593, 12)
# final_result
# Pass           12361
# Withdrawn      10156
# Fail            7052
# Distinction     3024
# Name: count, dtype: int64

# %%
# Goal: Create a merged dataset for analysis.
df_assess = pd.read_csv('/Users/hamzacharmaqe/Documents/Last Year/Project Metier/BigData_University_Quality/3_Data/Raw/OULAD/studentAssessment.csv')
df_merged = pd.merge(df_info, df_assess, on='id_student', how='inner')
print(df_merged.shape)  # ~173,912 rows
df_merged.to_csv('/Users/hamzacharmaqe/Documents/Last Year/Project Metier/BigData_University_Quality/3_Data/Processed/oulad_merged.csv', index=False)
# Out:
# (207319, 16)

# %%
# Add diversity (smaller, simpler dataset).
df_perf = pd.read_csv('/Users/hamzacharmaqe/Documents/Last Year/Project Metier/BigData_University_Quality/3_Data/Raw/Student_Performance/student-mat.csv')
print(df_perf.shape)  # (395, 33)
print(df_perf.columns)
# Out:
# (395, 33)
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# Run Pandas Profiling
from ydata_profiling import ProfileReport

df = pd.read_csv('/Users/hamzacharmaqe/Documents/Last Year/Project Metier/BigData_University_Quality/3_Data/Processed/oulad_merged.csv')
profile = ProfileReport(df, title="OULAD Data Quality Report", explorative=True)
profile.to_file('/Users/hamzacharmaqe/Documents/Last Year/Project Metier/BigData_University_Quality/3_Data/Documentation/OULAD_Profiling_Report.html')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## OVERVIEW: Phase 3 Goals
# ### By 22 Dec 2025, you must deliver:
#
# 1. Data Quality Evaluation Report (5–7 pages)
# 2. Before-Quality Metrics Table (Completeness, Accuracy, Consistency, Timeliness, Uniqueness)
# 3. Interactive Dashboard (optional) or charts
# 4. DQI (Data Quality Index) calculated
# 5. Top 5 Quality Issues prioritized for improvement
#
# - **Primary Dataset**: oulad_merged.csv (173,912 rows)
# - **Secondary**: student-mat.csv (395 rows) → for validation
